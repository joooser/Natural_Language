# %% [markdown]
# <a href="https://colab.research.google.com/github/joooser/Natural_Language/blob/main/HMM_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entrenando un Modelo Markoviano Latente (HMM)

# %% [markdown]
# ## Corpus de español:
#
# * AnCora | Github: https://github.com/UniversalDependencies/UD_Spanish-AnCora
#
# * usamos el conllu parser para leer el corpus: https://pypi.org/project/conllu/
#
# * Etiquetas Universal POS (Documentación): https://universaldependencies.org/u/pos/

# %%
#@title dependencias previas
# !pip install conllu
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting conllu
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.5.2
# Cloning into 'UD_Spanish-AnCora'...
# remote: Enumerating objects: 928, done.
# remote: Counting objects: 100% (181/181), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 928 (delta 128), reused 174 (delta 121), pack-reused 747
# Receiving objects: 100% (928/928), 337.55 MiB | 28.03 MiB/s, done.
# Resolving deltas: 100% (653/653), done.

# %%
#@title leyendo el corpus AnCora
from conllu import parse_incr 
wordList = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")
for tokenlist in parse_incr(data_file):
    print(tokenlist.serialize())
# Out:
# Streaming output truncated to the last 5000 lines.
# 25.1	_	_	PRON	p	_	_	_	26:nsubj	Entity=(CESSCASTAA200007042484c7--1-CorefType:ident,gstype:gen)
# 26	tuvieron	tener	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	22	acl	22:acl	_
# 27	que	que	SCONJ	cs	_	28	cc	28:cc	_
# 28	vender	vender	VERB	vmn0000	VerbForm=Inf	26	conj	26:conj	_
# 29	a	a	ADP	sps00	_	31	case	31:case	_
# 30	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	Entity=(CESSCASTAA200007042484s4.sn.73--2-gstype:gen
# 31	valor	valor	NOUN	ncms000	Gender=Masc|Number=Sing	28	obl	28:obl	_
# 32	muy	mucho	ADV	rg	_	33	advmod	33:advmod	_
# 33	inferior	inferior	ADJ	aq0cs0	Number=Sing	31	amod	31:amod	_
# 34-35	al	_	_	_	_	_	_	_	_
# 34	a	a	ADP	spcms	_	37	case	37:case	_
# 35	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	37	det	37:det	_
# 36	de	de	ADP	sps00	_	37	case	37:case	Entity=(CESSCASTAA200007042484s4.sn.86--2-gstype:gen
# 37	compra	compra	NOUN	ncfs000	Gender=Fem|Number=Sing	33	nmod	33:nmod	SpaceAfter=No|Entity=CESSCASTAA200007042484s4.sn.86)CESSCASTAA200007042484s4.sn.73)CESSCASTAA200007042484c8)
# 38	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 39	explicó	explicar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 40	Echeverría	Echeverría	PROPN	np00000	_	39	nsubj	39:nsubj	SpaceAfter=No|Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 41	.	.	PUNCT	fp	PunctType=Peri	39	punct	39:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s5
# # text = Añadió que los exportadores pidieron un aval del Estado por 22 millones de dólares para afrontar la crisis, pero el Instituto Hondureño del Café (IHCAFE), que maneja la política del sector, rechazó tal pretensión.
# 0.1	_	_	PRON	p	_	_	_	1:nsubj	Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 1	Añadió	añadir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 2	que	que	SCONJ	cs	_	5	mark	5:mark	_
# 3	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	4	det	4:det	Entity=(CESSCASTAA200007042484s5.sn.9--2-gstype:gen,HomoDD
# 4	exportadores	exportador	NOUN	ncmp000	Gender=Masc|Number=Plur	5	nsubj	5:nsubj	Entity=CESSCASTAA200007042484s5.sn.9)
# 5	pidieron	pedir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	1	ccomp	1:ccomp	_
# 6	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	7	det	7:det	Entity=(CESSCASTAA200007042484c10--2-gstype:gen
# 7	aval	aval	NOUN	ncms000	Gender=Masc|Number=Sing	5	obj	5:obj	_
# 8-9	del	_	_	_	_	_	_	_	_
# 8	de	de	ADP	spcms	_	10	case	10:case	_
# 9	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	10	det	10:det	_
# 10	Estado	Estado	PROPN	np00000	_	7	nmod	7:nmod	Entity=(CESSCASTAA200007042484c12-organization-1-gstype:spec)
# 11	por	por	ADP	sps00	_	13	case	13:case	_
# 12	22	22	NUM	_	NumForm=Digit|NumType=Card	13	nummod	13:nummod	Entity=(CESSCASTAA200007042484s5.sn.30-number-2-gstype:spec
# 13	millones	millón	NOUN	ncmp000	Gender=Masc|Number=Plur	7	nmod	7:nmod	_
# 14	de	de	ADP	sps00	_	15	case	15:case	_
# 15	dólares	dólar	NOUN	zm	NumForm=Digit	13	nmod	13:nmod	Entity=(CESSCASTAA200007042484s5.sn.38-number-1-gstype:spec)CESSCASTAA200007042484s5.sn.30)CESSCASTAA200007042484c10)
# 16	para	para	ADP	sps00	_	17	mark	17:mark	_
# 17	afrontar	afrontar	VERB	vmn0000	VerbForm=Inf	5	advcl	5:advcl	_
# 18	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	19	det	19:det	Entity=(CESSCASTAA200007042484c11--2-CorefType:ident,gstype:gen
# 19	crisis	crisis	NOUN	ncfn000	Gender=Fem	17	obj	17:obj	SpaceAfter=No|Entity=CESSCASTAA200007042484c11)
# 20	,	,	PUNCT	fc	PunctType=Comm	40	punct	40:punct	_
# 21	pero	pero	CCONJ	cc	_	40	cc	40:cc	_
# 22	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	23	det	23:det	Entity=(CESSCASTAA200007042484c9-organization-2-gstype:spec
# 23	Instituto	Instituto	PROPN	np00000	_	40	nsubj	40:nsubj	MWE=Instituto_Hondureño_del_Café|MWEPOS=PROPN
# 24	Hondureño	Hondureño	PROPN	_	_	23	flat	23:flat	_
# 25-26	del	_	_	_	_	_	_	_	_
# 25	de	de	ADP	_	_	27	case	27:case	_
# 26	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	27	det	27:det	_
# 27	Café	Café	PROPN	_	_	23	flat	23:flat	_
# 28	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	29	punct	29:punct	SpaceAfter=No|Entity=(CESSCASTAA200007042484c9-organization-2-CorefType:pred.definit,gstype:spec
# 29	IHCAFE	IHCAFE	PROPN	np00000	_	23	flat	23:flat	SpaceAfter=No
# 30	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	29	punct	29:punct	SpaceAfter=No|Entity=CESSCASTAA200007042484c9)
# 31	,	,	PUNCT	fc	PunctType=Comm	33	punct	33:punct	_
# 32	que	que	PRON	pr0cn000	PronType=Int,Rel	33	nsubj	33:nsubj	Entity=(CESSCASTAA200007042484c9-organization-1-CorefType:ident,gstype:spec)
# 33	maneja	manejar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	23	acl	23:acl	_
# 34	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	35	det	35:det	Entity=(CESSCASTAA200007042484s5.sn.72--2-gstype:gen,HomoDD
# 35	política	política	NOUN	ncfs000	Gender=Fem|Number=Sing	33	obj	33:obj	_
# 36-37	del	_	_	_	_	_	_	_	_
# 36	de	de	ADP	spcms	_	38	case	38:case	_
# 37	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	38:det	_
# 38	sector	sector	NOUN	ncms000	Gender=Masc|Number=Sing	35	nmod	35:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007042484c14--1-gstype:gen,HomoDD)CESSCASTAA200007042484s5.sn.72)
# 39	,	,	PUNCT	fc	PunctType=Comm	33	punct	33:punct	Entity=CESSCASTAA200007042484c9)
# 40	rechazó	rechazar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	5	conj	5:conj	_
# 41	tal	tal	DET	dd0cs0	Number=Sing|PronType=Dem	42	det	42:det	Entity=(CESSCASTAA200007042484c10--2-CorefType:ident,gstype:gen
# 42	pretensión	pretensión	NOUN	ncfs000	Gender=Fem|Number=Sing	40	obj	40:obj	SpaceAfter=No|Entity=CESSCASTAA200007042484c10)
# 43	.	.	PUNCT	fp	PunctType=Peri	1	punct	1:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s6
# # text = "Las empresas que murieron durante la crisis ya no se pueden recuperar", lamentó, y exhortó al Gobierno a promover más el café hondureño en el mercado internacional para impulsar una recuperación del sector, el principal de la economía del país.
# 1	"	"	PUNCT	fe	PunctType=Quot	16	punct	16:punct	SpaceAfter=No
# 2	Las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	3	det	3:det	Entity=(CESSCASTAA200007042484c2--2-CorefType:ident,gstype:gen
# 3	empresas	empresa	NOUN	ncfp000	Gender=Fem|Number=Plur	16	nsubj	16:nsubj	_
# 4	que	que	PRON	pr0cn000	PronType=Int,Rel	5	nsubj	5:nsubj	Entity=(CESSCASTAA200007042484c2--1-CorefType:ident,gstype:gen)
# 5	murieron	morir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	3	acl	3:acl	_
# 6	durante	durante	ADP	sps00	_	8	case	8:case	_
# 7	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	8:det	Entity=(CESSCASTAA200007042484c11--2-CorefType:ident,gstype:gen
# 8	crisis	crisis	NOUN	ncfn000	Gender=Fem	5	obl	5:obl	Entity=CESSCASTAA200007042484c11)CESSCASTAA200007042484c2)
# 9	ya	ya	ADV	rg	_	13	advmod	13:advmod	_
# 10	no	no	ADV	rn	Polarity=Neg	13	advmod	13:advmod	_
# 11	se	él	PRON	p0000000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	13	expl:pv	13:expl:pv	_
# 12	pueden	poder	AUX	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	13	aux	13:aux	_
# 13	recuperar	recuperar	VERB	vmn0000	VerbForm=Inf	16	xcomp	16:xcomp	SpaceAfter=No
# 14	"	"	PUNCT	fe	PunctType=Quot	13	punct	13:punct	SpaceAfter=No
# 15	,	,	PUNCT	fc	PunctType=Comm	13	punct	13:punct	_
# 16	lamentó	lamentar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	SpaceAfter=No
# 16.1	_	_	PRON	p	_	_	_	16:nsubj	Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 17	,	,	PUNCT	fc	PunctType=Comm	19	punct	19:punct	_
# 18	y	y	CCONJ	cc	_	19	cc	19:cc	_
# 18.1	_	_	PRON	p	_	_	_	19:nsubj	Entity=(CESSCASTAA200007042484c4-person-1-CorefType:ident,gstype:spec)
# 19	exhortó	exhortar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	16	conj	16:conj	_
# 20-21	al	_	_	_	_	_	_	_	_
# 20	a	a	ADP	spcms	_	22	case	22:case	_
# 21	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	22	det	22:det	_
# 22	Gobierno	Gobierno	PROPN	np00000	_	19	iobj	19:iobj	Entity=(CESSCASTAA200007042484c12-organization-1-CorefType:ident,gstype:spec)
# 23	a	a	ADP	sps00	_	24	mark	24:mark	_
# 24	promover	promover	VERB	vmn0000	VerbForm=Inf	19	xcomp	19:xcomp	_
# 25	más	más	ADV	rg	Degree=Cmp	24	advmod	24:advmod	_
# 26	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	27	det	27:det	Entity=(CESSCASTAA200007042484c16-other-2-gstype:spec
# 27	café	café	NOUN	ncms000	Gender=Masc|Number=Sing	24	obj	24:obj	_
# 28	hondureño	hondureño	ADJ	aq0ms0	Gender=Masc|Number=Sing	27	amod	27:amod	Entity=CESSCASTAA200007042484c16)
# 29	en	en	ADP	sps00	_	31	case	31:case	_
# 30	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	31	det	31:det	Entity=(CESSCASTAA200007042484c13--2-CorefType:ident,gstype:gen,HomoDD
# 31	mercado	mercado	NOUN	ncms000	Gender=Masc|Number=Sing	24	obl	24:obl	_
# 32	internacional	internacional	ADJ	aq0cs0	Number=Sing	31	amod	31:amod	Entity=CESSCASTAA200007042484c13)
# 33	para	para	ADP	sps00	_	34	mark	34:mark	_
# 34	impulsar	impulsar	VERB	vmn0000	VerbForm=Inf	24	advcl	24:advcl	_
# 35	una	uno	DET	di0fs0	Definite=Ind|Gender=Fem|Number=Sing|PronType=Art	36	det	36:det	Entity=(CESSCASTAA200007042484s6.sn.86--2-gstype:gen
# 36	recuperación	recuperación	NOUN	ncfs000	Gender=Fem|Number=Sing	34	obj	34:obj	_
# 37-38	del	_	_	_	_	_	_	_	_
# 37	de	de	ADP	spcms	_	39	case	39:case	_
# 38	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	39	det	39:det	_
# 39	sector	sector	NOUN	ncms000	Gender=Masc|Number=Sing	36	nmod	36:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007042484c14--1-CorefType:ident,gstype:gen,HomoDD
# 40	,	,	PUNCT	fc	PunctType=Comm	42	punct	42:punct	Entity=(CESSCASTAA200007042484c14--3-CorefType:pred.definit,gstype:gen
# 41	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	42	det	42:det	_
# 42	principal	principal	ADJ	aq0cs0	Number=Sing	39	appos	39:appos	_
# 43	de	de	ADP	sps00	_	45	case	45:case	_
# 44	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	45	det	45:det	Entity=(CESSCASTAA200007042484s6.sn.108--2-gstype:gen,HomoDD
# 45	economía	economía	NOUN	ncfs000	Gender=Fem|Number=Sing	42	nmod	42:nmod	_
# 46-47	del	_	_	_	_	_	_	_	_
# 46	de	de	ADP	spcms	_	48	case	48:case	_
# 47	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	48	det	48:det	_
# 48	país	país	NOUN	ncms000	Gender=Masc|Number=Sing	45	nmod	45:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007042484c15-place-1-CorefType:ident,gstype:spec)CESSCASTAA200007042484s6.sn.108)CESSCASTAA200007042484c14)CESSCASTAA200007042484c14)CESSCASTAA200007042484s6.sn.86)
# 49	.	.	PUNCT	fp	PunctType=Peri	16	punct	16:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s7
# # text = Las exportaciones de café hondureño en la cosecha 1999-2000, de unos 3,5 millones de sacos de 46 kilos, alcanzaron unos 300 millones de dólares hasta Junio pasado.
# 1	Las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200007042484s7.sn.2--2-gstype:gen,HomoDD
# 2	exportaciones	exportación	NOUN	ncfp000	Gender=Fem|Number=Plur	21	nsubj	21:nsubj	_
# 3	de	de	ADP	sps00	_	4	case	4:case	_
# 4	café	café	NOUN	ncms000	Gender=Masc|Number=Sing	2	nmod	2:nmod	Entity=(CESSCASTAA200007042484c16-other-1-CorefType:ident,gstype:spec
# 5	hondureño	hondureño	ADJ	aq0ms0	Gender=Masc|Number=Sing	4	amod	4:amod	Entity=CESSCASTAA200007042484c16)
# 6	en	en	ADP	sps00	_	8	case	8:case	_
# 7	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	8	det	8:det	Entity=(CESSCASTAA200007042484s7.sn.19--2-gstype:gen,HomoDD
# 8	cosecha	cosecha	NOUN	ncfs000	Gender=Fem|Number=Sing	2	nmod	2:nmod	_
# 9	1999-2000	1999-2000	NOUN	_	AdvType=Tim	8	appos	8:appos	SpaceAfter=No|Entity=(CESSCASTAA200007042484s7.sn.24-time-1-gstype:spec)CESSCASTAA200007042484s7.sn.19)
# 10	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	_
# 11	de	de	ADP	sps00	_	14	case	14:case	_
# 12	unos	uno	PRON	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	13	nmod	13:nmod	Entity=(CESSCASTAA200007042484s7.sn.31--3-gstype:gen
# 13	3,5	3.5	NUM	_	NumForm=Digit|NumType=Card	14	nummod	14:nummod	_
# 14	millones	millón	NOUN	ncmp000	Gender=Masc|Number=Plur	2	nmod	2:nmod	_
# 15	de	de	ADP	sps00	_	16	case	16:case	_
# 16	sacos	saco	NOUN	ncmp000	Gender=Masc|Number=Plur	14	nmod	14:nmod	_
# 17	de	de	ADP	sps00	_	19	case	19:case	_
# 18	46	46	NUM	_	NumForm=Digit|NumType=Card	19	nummod	19:nummod	Entity=(CESSCASTAA200007042484s7.sn.46-number-2-gstype:spec
# 19	kilos	kilo	NOUN	ncmp000	Gender=Masc|Number=Plur	16	nmod	16:nmod	SpaceAfter=No|Entity=CESSCASTAA200007042484s7.sn.46)CESSCASTAA200007042484s7.sn.31)
# 20	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	Entity=CESSCASTAA200007042484s7.sn.2)
# 21	alcanzaron	alcanzar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 22	unos	uno	PRON	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	23	nmod	23:nmod	Entity=(CESSCASTAA200007042484s7.sn.54-number-3-gstype:spec
# 23	300	300	NUM	_	NumForm=Digit|NumType=Card	24	nummod	24:nummod	_
# 24	millones	millón	NOUN	ncmp000	Gender=Masc|Number=Plur	21	obj	21:obj	_
# 25	de	de	ADP	sps00	_	26	case	26:case	_
# 26	dólares	dólar	NOUN	zm	NumForm=Digit	24	nmod	24:nmod	Entity=(CESSCASTAA200007042484s7.sn.63-number-1-gstype:spec)CESSCASTAA200007042484s7.sn.54)
# 27	hasta	hasta	ADP	sps00	_	28	case	28:case	_
# 28	Junio	Junio	NOUN	_	AdvType=Tim	21	obl	21:obl	Entity=(CESSCASTAA200007042484s7.sn.69-time-1-gstype:spec
# 29	pasado	pasado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	28	amod	28:amod	SpaceAfter=No|Entity=CESSCASTAA200007042484s7.sn.69)
# 30	.	.	PUNCT	fp	PunctType=Peri	21	punct	21:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000704-2484-s8
# # text = Honduras retendrá parte de su cosecha exportable en el nuevo ciclo, como determinaron los países exportadores en Mayo pasado en Londres, para estimular la subida del precio internacional del café, cuyo cultivo está en manos de unos 80.000 productores locales.
# 1	Honduras	Honduras	PROPN	np00000	_	2	nsubj	2:nsubj	Entity=(CESSCASTAA200007042484c18-organization-1-gstype:spec)
# 2	retendrá	retener	VERB	vmif3s0	Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin	0	root	0:root	_
# 3	parte	parte	NOUN	ncfs000	Gender=Fem|Number=Sing	2	obj	2:obj	Entity=(CESSCASTAA200007042484s8.sn.7--1-gstype:gen
# 4	de	de	ADP	sps00	_	6	case	6:case	_
# 5	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	6	det	6:det	Entity=(CESSCASTAA200007042484s8.sn.13--2-gstype:gen(CESSCASTAA200007042484c18-organization-1-CorefType:ident,gstype:spec)
# 6	cosecha	cosecha	NOUN	ncfs000	Gender=Fem|Number=Sing	3	nmod	3:nmod	_
# 7	exportable	exportable	ADJ	aq0cs0	Number=Sing	6	amod	6:amod	Entity=CESSCASTAA200007042484s8.sn.13)CESSCASTAA200007042484s8.sn.7)
# 8	en	en	ADP	sps00	_	11	case	11:case	_
# 9	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	11	det	11:det	Entity=(CESSCASTAA200007042484s8.sn.24--3-gstype:gen,HomoDD
# 10	nuevo	nuevo	ADJ	aq0ms0	Gender=Masc|Number=Sing	11	amod	11:amod	_
# 11	ciclo	ciclo	NOUN	ncms000	Gender=Masc|Number=Sing	2	obl	2:obl	SpaceAfter=No|Entity=CESSCASTAA200007042484s8.sn.24)
# 12	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	_
# 13	como	como	SCONJ	cs	_	14	mark	14:mark	_
# 14	determinaron	determinar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	2	advcl	2:advcl	_
# 15	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	16	det	16:det	Entity=(CESSCASTAA200007042484s8.sn.38--2-gstype:gen
# 16	países	país	NOUN	ncmp000	Gender=Masc|Number=Plur	14	nsubj	14:nsubj	_
# 17	exportadores	exportador	ADJ	aq0mp0	Gender=Masc|Number=Plur	16	amod	16:amod	Entity=CESSCASTAA200007042484s8.sn.38)
# 18	en	en	ADP	sps00	_	19	case	19:case	_
# 19	Mayo	Mayo	NOUN	_	AdvType=Tim	14	obl	14:obl	Entity=(CESSCASTAA200007042484s8.sn.49-time-1-gstype:spec
# 20	pasado	pasado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	19	amod	19:amod	Entity=CESSCASTAA200007042484s8.sn.49)
# 21	en	en	ADP	sps00	_	22	case	22:case	_
# 22	Londres	Londres	PROPN	np00000	_	14	obl	14:obl	SpaceAfter=No|Entity=(CESSCASTAA200007042484s8.sn.58-place-1-gstype:spec)
# 23	,	,	PUNCT	fc	PunctType=Comm	25	punct	25:punct	_
# 24	para	para	ADP	sps00	_	25	mark	25:mark	_
# 25	estimular	estimular	VERB	vmn0000	VerbForm=Inf	14	advcl	14:advcl	_
# 26	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	27	det	27:det	Entity=(CESSCASTAA200007042484s8.sn.68--2-gstype:gen,HomoDD
# 27	subida	subida	NOUN	ncfs000	Gender=Fem|Number=Sing	25	obj	25:obj	_
# 28-29	del	_	_	_	_	_	_	_	_
# 28	de	de	ADP	spcms	_	30	case	30:case	_
# 29	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	30	det	30:det	_
# 30	precio	precio	NOUN	ncms000	Gender=Masc|Number=Sing	27	nmod	27:nmod	Entity=(CESSCASTAA200007042484c17--1-CorefType:ident,gstype:gen,HomoDD
# 31	internacional	internacional	ADJ	aq0cs0	Number=Sing	30	amod	30:amod	_
# 32-33	del	_	_	_	_	_	_	_	_
# 32	de	de	ADP	spcms	_	34	case	34:case	_
# 33	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	34	det	34:det	_
# 34	café	café	NOUN	ncms000	Gender=Masc|Number=Sing	30	nmod	30:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007042484c1--1-CorefType:ident,gstype:gen,HomoDD
# 35	,	,	PUNCT	fc	PunctType=Comm	44	punct	44:punct	_
# 36	cuyo	cuyo	PRON	pr0ms000	Gender=Masc|Number=Sing|Poss=Yes|PronType=Int,Rel	37	nmod	37:nmod	Entity=(CESSCASTAA200007042484s8.sn.90--2-gstype:gen(CESSCASTAA200007042484c1--1-CorefType:ident,gstype:gen)
# 37	cultivo	cultivo	NOUN	ncms000	Gender=Masc|Number=Sing	44	nsubj	44:nsubj	Entity=CESSCASTAA200007042484s8.sn.90)
# 38	está	estar	AUX	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	44	cop	44:cop	_
# 39	en	en	ADP	sps00	_	44	case	44:case	MWE=en_manos_de|MWEPOS=ADP
# 40	manos	manos	NOUN	_	_	39	fixed	39:fixed	_
# 41	de	de	ADP	_	_	39	fixed	39:fixed	_
# 42	unos	uno	PRON	di0mp0	Gender=Masc|Number=Plur|PronType=Ind	43	nmod	43:nmod	Entity=(CESSCASTAA200007042484s8.sn.100--3-gstype:gen
# 43	80.000	80000	NUM	_	NumForm=Digit|NumType=Card	44	nummod	44:nummod	_
# 44	productores	productor	NOUN	ncmp000	Gender=Masc|Number=Plur	34	acl	34:acl	_
# 45	locales	local	ADJ	aq0cp0	Number=Plur	44	amod	44:amod	SpaceAfter=No|Entity=CESSCASTAA200007042484s8.sn.100)CESSCASTAA200007042484c1)CESSCASTAA200007042484c17)CESSCASTAA200007042484s8.sn.68)
# 46	.	.	PUNCT	fp	PunctType=Peri	2	punct	2:punct	_
#
#
# # global.Entity = eid-etype-head-other
# # newdoc id = CESS-CAST-AA-20000705-2692
# # sent_id = CESS-CAST-AA-20000705-2692-s1
# # text = Cientos de personas armadas con arcos y flechas impidieron que la Alta Comisaría de las Naciones Unidas para los Refugiados (ACNUR) reanudara sus actividades de repatriación de timorenses en tres campamentos de refugiados de Nussa Tengara (Timor Occidentel).
# 1	Cientos	ciento	NUM	pn0cp000	Number=Plur|NumType=Card	9	nsubj	9:nsubj	Entity=(CESSCASTAA200007052692c2--1-gstype:gen
# 2	de	de	ADP	sps00	_	3	case	3:case	_
# 3	personas	persona	NOUN	ncfp000	Gender=Fem|Number=Plur	1	nmod	1:nmod	_
# 4	armadas	armado	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	3	amod	3:amod	_
# 5	con	con	ADP	sps00	_	6	case	6:case	_
# 6	arcos	arco	NOUN	ncmp000	Gender=Masc|Number=Plur	4	obl	4:obl	_
# 7	y	y	CCONJ	cc	_	8	cc	8:cc	_
# 8	flechas	flecha	NOUN	ncfp000	Gender=Fem|Number=Plur	6	conj	6:conj	Entity=CESSCASTAA200007052692c2)
# 9	impidieron	impedir	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 10	que	que	SCONJ	cs	_	24	mark	24:mark	_
# 11	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	12	det	12:det	Entity=(CESSCASTAA200007052692c1-organization-2-gstype:spec
# 12	Alta	Alta	PROPN	np00000	_	24	nsubj	24:nsubj	MWE=Alta_Comisaría_de_las_Naciones_Unidas_para_los_Refugiados|MWEPOS=PROPN
# 13	Comisaría	Comisaría	PROPN	_	_	12	flat	12:flat	_
# 14	de	de	ADP	_	_	16	case	16:case	_
# 15	las	el	DET	_	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	16	det	16:det	_
# 16	Naciones	Naciones	PROPN	_	_	12	flat	12:flat	_
# 17	Unidas	Unidas	PROPN	_	_	12	flat	12:flat	_
# 18	para	para	ADP	_	_	20	case	20:case	_
# 19	los	el	DET	_	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	20	det	20:det	_
# 20	Refugiados	Refugiados	PROPN	_	_	12	flat	12:flat	_
# 21	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	22	punct	22:punct	SpaceAfter=No|Entity=(CESSCASTAA200007052692c1-organization-2-CorefType:pred.definit,gstype:spec
# 22	ACNUR	ACNUR	PROPN	np00000	_	12	flat	12:flat	SpaceAfter=No
# 23	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	22	punct	22:punct	Entity=CESSCASTAA200007052692c1)CESSCASTAA200007052692c1)
# 24	reanudara	reanudar	VERB	vmsi3s0	Mood=Sub|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	9	ccomp	9:ccomp	_
# 25	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	26	det	26:det	Entity=(CESSCASTAA200007052692c8--2-gstype:gen(CESSCASTAA200007052692c1-organization-1-CorefType:ident,gstype:spec)
# 26	actividades	actividad	NOUN	ncfp000	Gender=Fem|Number=Plur	24	obj	24:obj	_
# 27	de	de	ADP	sps00	_	28	case	28:case	_
# 28	repatriación	repatriación	NOUN	ncfs000	Gender=Fem|Number=Sing	26	nmod	26:nmod	_
# 29	de	de	ADP	sps00	_	30	case	30:case	_
# 30	timorenses	timorense	NOUN	nccp000	Number=Plur	28	nmod	28:nmod	Entity=(CESSCASTAA200007052692s1.sn.56--1-gstype:gen)CESSCASTAA200007052692c8)
# 31	en	en	ADP	sps00	_	33	case	33:case	_
# 32	tres	tres	NUM	dn0cp0	Number=Plur|NumType=Card	33	nummod	33:nummod	Entity=(CESSCASTAA200007052692c6--2-gstype:gen
# 33	campamentos	campamento	NOUN	ncmp000	Gender=Masc|Number=Plur	24	obl	24:obl	_
# 34	de	de	ADP	sps00	_	35	case	35:case	_
# 35	refugiados	refugiado	NOUN	ncmp000	Gender=Masc|Number=Plur	33	nmod	33:nmod	_
# 36	de	de	ADP	sps00	_	37	case	37:case	_
# 37	Nussa	Nussa	PROPN	np00000	_	35	nmod	35:nmod	MWE=Nussa_Tengara|MWEPOS=PROPN|ClusterId[1]=CESS-CAST-AA-20000705-2692-c9|ClusterType[1]=Spec.location|MentionSpan[1]=37-38|ClusterId[2]=CESS-CAST-AA-20000705-2692-s1.sn.76|ClusterType[2]=Spec.location|MentionSpan[2]=37-42|Entity=(CESSCASTAA200007052692s1.sn.76-place-1-gstype:spec(CESSCASTAA200007052692c9-place-1-gstype:spec
# 38	Tengara	Tengara	PROPN	_	_	37	flat	37:flat	Entity=CESSCASTAA200007052692c9)
# 39	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	40	punct	40:punct	SpaceAfter=No|Entity=(CESSCASTAA200007052692c3-place-2-gstype:spec
# 40	Timor	Timor	PROPN	np00000	_	37	flat	37:flat	MWE=Timor_Occidentel|MWEPOS=PROPN
# 41	Occidentel	Occidentel	PROPN	_	_	40	flat	40:flat	SpaceAfter=No
# 42	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	40	punct	40:punct	SpaceAfter=No|Entity=CESSCASTAA200007052692c3)CESSCASTAA200007052692s1.sn.76)CESSCASTAA200007052692c6)
# 43	.	.	PUNCT	fp	PunctType=Peri	9	punct	9:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s2
# # text = Según un portavoz de la agencia multilateral, residentes indonesios de Timor Occidental bloquearon las rutas de acceso que conectan Kupang, la capital de esta provincia indonesia, con los centros de refugiados de Noelbaky, Tuapukan y Naibonat.
# 1	Según	según	ADP	sps00	_	3	case	3:case	_
# 2	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	3	det	3:det	Entity=(CESSCASTAA200007052692s2.sn.5--2-gstype:gen
# 3	portavoz	portavoz	NOUN	nccs000	Number=Sing	14	obl	14:obl	_
# 4	de	de	ADP	sps00	_	6	case	6:case	_
# 5	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	6	det	6:det	Entity=(CESSCASTAA200007052692c1-organization-2-CorefType:ident,gstype:spec
# 6	agencia	agencia	NOUN	ncfs000	Gender=Fem|Number=Sing	3	nmod	3:nmod	_
# 7	multilateral	multilateral	ADJ	aq0cs0	Number=Sing	6	amod	6:amod	SpaceAfter=No|Entity=CESSCASTAA200007052692c1)CESSCASTAA200007052692s2.sn.5)
# 8	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	_
# 9	residentes	residente	NOUN	nccp000	Number=Plur	14	nsubj	14:nsubj	Entity=(CESSCASTAA200007052692c2--1-CorefType:ident,gstype:gen
# 10	indonesios	indonesio	ADJ	aq0mp0	Gender=Masc|Number=Plur	9	amod	9:amod	_
# 11	de	de	ADP	sps00	_	12	case	12:case	_
# 12	Timor	Timor	PROPN	np00000	_	9	nmod	9:nmod	MWE=Timor_Occidental|MWEPOS=PROPN|Entity=(CESSCASTAA200007052692c3-place-1-CorefType:ident,gstype:spec
# 13	Occidental	Occidental	PROPN	_	_	12	flat	12:flat	Entity=CESSCASTAA200007052692c3)CESSCASTAA200007052692c2)
# 14	bloquearon	bloquear	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 15	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	16	det	16:det	Entity=(CESSCASTAA200007052692c4--2-gstype:gen,HomoDD
# 16	rutas	ruta	NOUN	ncfp000	Gender=Fem|Number=Plur	14	obj	14:obj	_
# 17	de	de	ADP	sps00	_	18	case	18:case	_
# 18	acceso	acceso	NOUN	ncms000	Gender=Masc|Number=Sing	16	nmod	16:nmod	_
# 19	que	que	PRON	pr0cn000	PronType=Int,Rel	20	nsubj	20:nsubj	Entity=(CESSCASTAA200007052692c4--1-CorefType:ident,gstype:gen)
# 20	conectan	conectar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	16	acl	16:acl	_
# 21	Kupang	Kupang	PROPN	np00000	_	20	obj	20:obj	SpaceAfter=No|Entity=(CESSCASTAA200007052692c5-place-1-gstype:spec
# 22	,	,	PUNCT	fc	PunctType=Comm	24	punct	24:punct	Entity=(CESSCASTAA200007052692c5-place-3-CorefType:pred.definit,gstype:spec
# 23	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	24	det	24:det	_
# 24	capital	capital	NOUN	ncfs000	Gender=Fem|Number=Sing	21	appos	21:appos	_
# 25	de	de	ADP	sps00	_	27	case	27:case	_
# 26	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	27	det	27:det	Entity=(CESSCASTAA200007052692c3-place-2-CorefType:ident,gstype:spec
# 27	provincia	provincia	NOUN	ncfs000	Gender=Fem|Number=Sing	24	nmod	24:nmod	_
# 28	indonesia	indonesio	ADJ	aq0fs0	Gender=Fem|Number=Sing	27	amod	27:amod	SpaceAfter=No|Entity=CESSCASTAA200007052692c3)
# 29	,	,	PUNCT	fc	PunctType=Comm	24	punct	24:punct	Entity=CESSCASTAA200007052692c5)CESSCASTAA200007052692c5)
# 30	con	con	ADP	sps00	_	32	case	32:case	_
# 31	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	32	det	32:det	Entity=(CESSCASTAA200007052692c6--2-CorefType:ident,gstype:gen,HomoDD
# 32	centros	centro	NOUN	ncmp000	Gender=Masc|Number=Plur	20	obj	20:obj	_
# 33	de	de	ADP	sps00	_	34	case	34:case	_
# 34	refugiados	refugiado	NOUN	ncmp000	Gender=Masc|Number=Plur	32	nmod	32:nmod	_
# 35	de	de	ADP	sps00	_	36	case	36:case	_
# 36	Noelbaky	Noelbaky	PROPN	np00000	_	32	nmod	32:nmod	SpaceAfter=No
# 37	,	,	PUNCT	fc	PunctType=Comm	38	punct	38:punct	_
# 38	Tuapukan	Tuapukan	PROPN	np00000	_	36	conj	36:conj	_
# 39	y	y	CCONJ	cc	_	40	cc	40:cc	_
# 40	Naibonat	Naibonat	PROPN	np00000	_	36	conj	36:conj	SpaceAfter=No|Entity=CESSCASTAA200007052692c6)CESSCASTAA200007052692c4)
# 41	.	.	PUNCT	fp	PunctType=Peri	14	punct	14:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s3
# # text = El portavoz de la oficina de ACNUR en Dili, Joseph Yeo, dijo que "es imposible saber cuándo podremos reanudar nuestras actividades porque hay un malestar generalizado allí".
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200007052692c7-person-2-gstype:spec
# 2	portavoz	portavoz	NOUN	nccs000	Number=Sing	14	nsubj	14:nsubj	_
# 3	de	de	ADP	sps00	_	5	case	5:case	_
# 4	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	5	det	5:det	Entity=(CESSCASTAA200007052692s3.sn.10-organization-2-gstype:spec
# 5	oficina	oficina	NOUN	ncfs000	Gender=Fem|Number=Sing	2	nmod	2:nmod	_
# 6	de	de	ADP	sps00	_	7	case	7:case	_
# 7	ACNUR	ACNUR	PROPN	np00000	_	5	nmod	5:nmod	Entity=(CESSCASTAA200007052692c1-organization-1-CorefType:ident,gstype:spec)
# 8	en	en	ADP	sps00	_	9	case	9:case	_
# 9	Dili	Dili	PROPN	np00000	_	5	nmod	5:nmod	SpaceAfter=No|Entity=(CESSCASTAA200007052692s3.sn.24-place-1-gstype:spec)CESSCASTAA200007052692s3.sn.10)
# 10	,	,	PUNCT	fc	PunctType=Comm	11	punct	11:punct	Entity=(CESSCASTAA200007052692c7-person-2-CorefType:pred.definit,gstype:spec
# 11	Joseph	Joseph	PROPN	np00000	_	2	appos	2:appos	MWE=Joseph_Yeo|MWEPOS=PROPN
# 12	Yeo	Yeo	PROPN	_	_	11	flat	11:flat	SpaceAfter=No
# 13	,	,	PUNCT	fc	PunctType=Comm	11	punct	11:punct	Entity=CESSCASTAA200007052692c7)CESSCASTAA200007052692c7)
# 14	dijo	decir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 15	que	que	SCONJ	cs	_	18	mark	18:mark	_
# 16	"	"	PUNCT	fe	PunctType=Quot	18	punct	18:punct	SpaceAfter=No
# 17	es	ser	AUX	vsip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	18	cop	18:cop	_
# 18	imposible	imposible	ADJ	aq0cs0	Number=Sing	14	ccomp	14:ccomp	_
# 19	saber	saber	AUX	vmn0000	VerbForm=Inf	22	aux	22:aux	_
# 20	cuándo	cuándo	PRON	pt000000	PronType=Ind	22	obl	22:obl	_
# 20.1	_	_	PRON	p	_	_	_	22:nsubj	Entity=(CESSCASTAA200007052692c1-organization-1-CorefType:ident,gstype:spec)
# 21	podremos	poder	AUX	vmif1p0	Mood=Ind|Number=Plur|Person=1|Tense=Fut|VerbForm=Fin	22	aux	22:aux	_
# 22	reanudar	reanudar	VERB	vmn0000	VerbForm=Inf	18	csubj	18:csubj	_
# 23	nuestras	nuestro	DET	dp1fpp	Gender=Fem|Number=Plur|Number[psor]=Plur|Person=1|Poss=Yes|PronType=Prs	24	det	24:det	Entity=(CESSCASTAA200007052692c8--2-CorefType:ident,gstype:gen(CESSCASTAA200007052692c1-organization-1-CorefType:ident,gstype:spec)
# 24	actividades	actividad	NOUN	ncfp000	Gender=Fem|Number=Plur	22	obj	22:obj	Entity=CESSCASTAA200007052692c8)
# 25	porque	porque	SCONJ	cs	_	26	mark	26:mark	_
# 26	hay	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	18	advcl	18:advcl	_
# 27	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	28	det	28:det	Entity=(CESSCASTAA200007052692s3.sn.65--2-gstype:gen
# 28	malestar	malestar	NOUN	ncms000	Gender=Masc|Number=Sing	26	obj	26:obj	_
# 29	generalizado	generalizado	ADJ	aq0msp	Gender=Masc|Number=Sing|VerbForm=Part	28	amod	28:amod	Entity=CESSCASTAA200007052692s3.sn.65)
# 30	allí	allí	ADV	rg	_	26	advmod	26:advmod	SpaceAfter=No
# 31	"	"	PUNCT	fe	PunctType=Quot	18	punct	18:punct	SpaceAfter=No
# 32	.	.	PUNCT	fp	PunctType=Peri	14	punct	14:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s4
# # text = Los habitantes de Nussa Tengara "están descontentos porque muchos de los paramilitares han atacado a los residentes locales y se quejan de que toda la ayuda gubernamental e internacional se canaliza exclusivamente para los refugiados", indicó Yeo.
# 1	Los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200007052692c10--2-gstype:gen,HomoDD
# 2	habitantes	habitante	NOUN	nccp000	Number=Plur	8	nsubj	8:nsubj	_
# 3	de	de	ADP	sps00	_	4	case	4:case	_
# 4	Nussa	Nussa	PROPN	np00000	_	2	nmod	2:nmod	MWE=Nussa_Tengara|MWEPOS=PROPN|Entity=(CESSCASTAA200007052692c9-place-1-CorefType:ident,gstype:spec
# 5	Tengara	Tengara	PROPN	_	_	4	flat	4:flat	Entity=CESSCASTAA200007052692c9)CESSCASTAA200007052692c10)
# 6	"	"	PUNCT	fe	PunctType=Quot	8	punct	8:punct	SpaceAfter=No
# 7	están	estar	AUX	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	8	cop	8:cop	_
# 8	descontentos	descontento	ADJ	aq0mp0	Gender=Masc|Number=Plur	39	ccomp	39:ccomp	_
# 9	porque	porque	SCONJ	cs	_	15	mark	15:mark	_
# 10	muchos	mucho	PRON	pi0mp000	Gender=Masc|Number=Plur|NumType=Card|PronType=Ind	15	nsubj	15:nsubj	Entity=(CESSCASTAA200007052692s4.sn.24--1-gstype:gen
# 11	de	de	ADP	sps00	_	13	case	13:case	_
# 12	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	13	det	13:det	Entity=(CESSCASTAA200007052692s4.sn.30--2-gstype:gen,HomoDD
# 13	paramilitares	paramilitar	ADJ	aq0cp0	Number=Plur	10	amod	10:amod	Entity=CESSCASTAA200007052692s4.sn.30)CESSCASTAA200007052692s4.sn.24)
# 14	han	haber	AUX	vaip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	15	aux	15:aux	_
# 15	atacado	atacar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	8	advcl	8:advcl	_
# 16	a	a	ADP	sps00	_	18	case	18:case	_
# 17	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	18	det	18:det	Entity=(CESSCASTAA200007052692c10--2-CorefType:ident,gstype:gen,HomoDD
# 18	residentes	residente	NOUN	nccp000	Number=Plur	15	obj	15:obj	_
# 19	locales	local	ADJ	aq0cp0	Number=Plur	18	amod	18:amod	Entity=CESSCASTAA200007052692c10)
# 20	y	y	CCONJ	cc	_	22	cc	22:cc	_
# 20.1	_	_	PRON	p	_	_	_	22:nsubj	Entity=(CESSCASTAA200007052692c10--1-CorefType:ident,gstype:gen)
# 21	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	22	expl:pv	22:expl:pv	_
# 22	quejan	quejar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	8	conj	8:conj	_
# 23	de	de	ADP	sps00	_	32	mark	32:mark	_
# 24	que	que	SCONJ	cs	_	32	mark	32:mark	_
# 25	toda	todo	DET	di0fs0	Gender=Fem|Number=Sing|PronType=Tot	26	det	26:det	Entity=(CESSCASTAA200007052692s4.sn.65--3-gstype:gen
# 26	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	27	det	27:det	_
# 27	ayuda	ayuda	NOUN	ncfs000	Gender=Fem|Number=Sing	32	nsubj	32:nsubj	_
# 28	gubernamental	gubernamental	ADJ	aq0cs0	Number=Sing	27	amod	27:amod	_
# 29	e	e	CCONJ	cc	_	30	cc	30:cc	_
# 30	internacional	internacional	ADJ	aq0cs0	Number=Sing	28	conj	28:conj	Entity=CESSCASTAA200007052692s4.sn.65)
# 31	se	él	PRON	p0000000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	32	expl:pass	32:expl:pass	_
# 32	canaliza	canalizar	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	22	ccomp	22:ccomp	_
# 33	exclusivamente	exclusivamente	ADV	rg	_	32	advmod	32:advmod	_
# 34	para	para	ADP	sps00	_	33	case	33:case	_
# 35	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	36	det	36:det	Entity=(CESSCASTAA200007052692s4.sn.90--2-gstype:gen,HomoDD
# 36	refugiados	refugiado	NOUN	ncmp000	Gender=Masc|Number=Plur	33	nmod	33:nmod	SpaceAfter=No|Entity=CESSCASTAA200007052692s4.sn.90)
# 37	"	"	PUNCT	fe	PunctType=Quot	8	punct	8:punct	SpaceAfter=No
# 38	,	,	PUNCT	fc	PunctType=Comm	8	punct	8:punct	_
# 39	indicó	indicar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 40	Yeo	Yeo	PROPN	np00000	_	39	nsubj	39:nsubj	SpaceAfter=No|Entity=(CESSCASTAA200007052692c7-person-1-CorefType:ident,gstype:spec)
# 41	.	.	PUNCT	fp	PunctType=Peri	39	punct	39:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s5
# # text = La ACNUR calcula que unas 95.000 personas de Timor Oriental continúan en centros de refugiados de Nussa Tengara.
# 1	La	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA200007052692c1-organization-2-CorefType:ident,gstype:spec
# 2	ACNUR	ACNUR	PROPN	np00000	_	3	nsubj	3:nsubj	Entity=CESSCASTAA200007052692c1)
# 3	calcula	calcular	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 4	que	que	SCONJ	cs	_	11	mark	11:mark	_
# 5	unas	uno	PRON	di0fp0	Gender=Fem|Number=Plur|PronType=Ind	6	nmod	6:nmod	Entity=(CESSCASTAA200007052692s5.sn.12--3-gstype:gen
# 6	95.000	95000	NUM	_	NumForm=Digit|NumType=Card	7	nummod	7:nummod	_
# 7	personas	persona	NOUN	ncfp000	Gender=Fem|Number=Plur	11	nsubj	11:nsubj	_
# 8	de	de	ADP	sps00	_	9	case	9:case	_
# 9	Timor	Timor	PROPN	np00000	_	7	nmod	7:nmod	MWE=Timor_Oriental|MWEPOS=PROPN|Entity=(CESSCASTAA200007052692c14-place-1-gstype:spec
# 10	Oriental	Oriental	PROPN	_	_	9	flat	9:flat	Entity=CESSCASTAA200007052692c14)CESSCASTAA200007052692s5.sn.12)
# 11	continúan	continuar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	3	ccomp	3:ccomp	_
# 12	en	en	ADP	sps00	_	13	case	13:case	_
# 13	centros	centro	NOUN	ncmp000	Gender=Masc|Number=Plur	11	obl	11:obl	Entity=(CESSCASTAA200007052692s5.sn.29--1-gstype:gen
# 14	de	de	ADP	sps00	_	15	case	15:case	_
# 15	refugiados	refugiado	NOUN	ncmp000	Gender=Masc|Number=Plur	13	nmod	13:nmod	_
# 16	de	de	ADP	sps00	_	17	case	17:case	_
# 17	Nussa	Nussa	PROPN	np00000	_	13	nmod	13:nmod	MWE=Nussa_Tengara|MWEPOS=PROPN|Entity=(CESSCASTAA200007052692c9-place-1-CorefType:ident,gstype:spec
# 18	Tengara	Tengara	PROPN	_	_	17	flat	17:flat	SpaceAfter=No|Entity=CESSCASTAA200007052692c9)CESSCASTAA200007052692s5.sn.29)
# 19	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s6
# # text = Yeo lamentó la demora en reiniciar el trabajo de ACNUR dado que las autoridades de Indonesia acordaron esta semana cumplir las demandas de la organización internacional.
# 1	Yeo	Yeo	PROPN	np00000	_	2	nsubj	2:nsubj	Entity=(CESSCASTAA200007052692c7-person-1-CorefType:ident,gstype:spec)
# 2	lamentó	lamentar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 3	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	4	det	4:det	Entity=(CESSCASTAA200007052692s6.sn.7--2-gstype:gen,HomoDD
# 4	demora	demora	NOUN	ncfs000	Gender=Fem|Number=Sing	2	obj	2:obj	_
# 5	en	en	ADP	sps00	_	6	mark	6:mark	_
# 6	reiniciar	reiniciar	VERB	vmn0000	VerbForm=Inf	4	acl	4:acl	_
# 7	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	8	det	8:det	Entity=(CESSCASTAA200007052692c8--2-CorefType:ident,gstype:gen,HomoDD
# 8	trabajo	trabajo	NOUN	ncms000	Gender=Masc|Number=Sing	6	obj	6:obj	_
# 9	de	de	ADP	sps00	_	10	case	10:case	_
# 10	ACNUR	ACNUR	PROPN	np00000	_	8	nmod	8:nmod	Entity=(CESSCASTAA200007052692c1-organization-1-CorefType:ident,gstype:spec)CESSCASTAA200007052692c8)CESSCASTAA200007052692s6.sn.7)
# 11	dado	dado	NOUN	cs	_	17	mark	17:mark	MWE=dado_que|MWEPOS=SCONJ
# 12	que	que	SCONJ	_	_	11	fixed	11:fixed	_
# 13	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	14	det	14:det	Entity=(CESSCASTAA200007052692s6.sn.32--2-gstype:gen,HomoDD
# 14	autoridades	autoridad	NOUN	ncfp000	Gender=Fem|Number=Plur	17	nsubj	17:nsubj	_
# 15	de	de	ADP	sps00	_	16	case	16:case	_
# 16	Indonesia	Indonesia	PROPN	np00000	_	14	nmod	14:nmod	Entity=(CESSCASTAA200007052692c17-place-1-gstype:spec)CESSCASTAA200007052692s6.sn.32)
# 17	acordaron	acordar	VERB	vmis3p0	Mood=Ind|Number=Plur|Person=3|Tense=Past|VerbForm=Fin	2	advcl	2:advcl	_
# 18	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	19	det	19:det	Entity=(CESSCASTAA200007052692s6.sn.45--2-gstype:gen
# 19	semana	semana	NOUN	ncfs000	Gender=Fem|Number=Sing	17	obl	17:obl	Entity=CESSCASTAA200007052692s6.sn.45)
# 20	cumplir	cumplir	VERB	vmn0000	VerbForm=Inf	17	xcomp	17:xcomp	_
# 21	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	22	det	22:det	Entity=(CESSCASTAA200007052692c11--2-gstype:gen,HomoDD
# 22	demandas	demanda	NOUN	ncfp000	Gender=Fem|Number=Plur	20	obj	20:obj	_
# 23	de	de	ADP	sps00	_	25	case	25:case	_
# 24	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	25	det	25:det	Entity=(CESSCASTAA200007052692c1-organization-2-CorefType:ident,gstype:spec
# 25	organización	organización	NOUN	ncfs000	Gender=Fem|Number=Sing	22	nmod	22:nmod	_
# 26	internacional	internacional	ADJ	aq0cs0	Number=Sing	25	amod	25:amod	SpaceAfter=No|Entity=CESSCASTAA200007052692c1)CESSCASTAA200007052692c11)
# 27	.	.	PUNCT	fp	PunctType=Peri	2	punct	2:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s7
# # text = Entre estas demandas destacan "la vigilancia policial durante las 24 horas del día de los campamentos de refugiados y la separación de los malos elementos que viven en las instalaciones", según la ACNUR.
# 1	Entre	entre	ADP	sps00	_	3	case	3:case	_
# 2	estas	este	DET	dd0fp0	Gender=Fem|Number=Plur|PronType=Dem	3	det	3:det	Entity=(CESSCASTAA200007052692c11--2-CorefType:ident,gstype:gen
# 3	demandas	demanda	NOUN	ncfp000	Gender=Fem|Number=Plur	4	obl	4:obl	Entity=CESSCASTAA200007052692c11)
# 4	destacan	destacar	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	0	root	0:root	_
# 5	"	"	PUNCT	fe	PunctType=Quot	7	punct	7:punct	SpaceAfter=No|Entity=(CESSCASTAA200007052692s7.sn.12--3-gstype:gen
# 6	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	7	det	7:det	Entity=(CESSCASTAA200007052692s7.sn.14--2-gstype:gen,HomoDD
# 7	vigilancia	vigilancia	NOUN	ncfs000	Gender=Fem|Number=Sing	4	nsubj	4:nsubj	ClusterId[1]=CESS-CAST-AA-20000705-2692-s7.sn.12|ClusterType[1]=Gen|MentionSpan[1]=5-33|ClusterId[2]=CESS-CAST-AA-20000705-2692-s7.sn.14|ClusterType[2]=Gen|MentionSpan[2]=6-20|MentionMisc[2]=HomoDD
# 8	policial	policial	ADJ	aq0cs0	Number=Sing	7	amod	7:amod	_
# 9	durante	durante	ADP	sps00	_	12	case	12:case	_
# 10	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	11	det	11:det	Entity=(CESSCASTAA200007052692s7.sn.25-number-3-gstype:spec
# 11	24	24	NUM	_	NumForm=Digit|NumType=Card	12	nummod	12:nummod	_
# 12	horas	hora	NOUN	ncfp000	Gender=Fem|Number=Plur	7	nmod	7:nmod	_
# 13-14	del	_	_	_	_	_	_	_	_
# 13	de	de	ADP	spcms	_	15	case	15:case	_
# 14	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	15	det	15:det	_
# 15	día	día	NOUN	ncms000	Gender=Masc|Number=Sing	12	nmod	12:nmod	Entity=CESSCASTAA200007052692s7.sn.25)
# 16	de	de	ADP	sps00	_	18	case	18:case	_
# 17	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	18	det	18:det	Entity=(CESSCASTAA200007052692c13--2-gstype:gen,HomoDD
# 18	campamentos	campamento	NOUN	ncmp000	Gender=Masc|Number=Plur	7	nmod	7:nmod	_
# 19	de	de	ADP	sps00	_	20	case	20:case	_
# 20	refugiados	refugiado	NOUN	ncmp000	Gender=Masc|Number=Plur	18	nmod	18:nmod	Entity=CESSCASTAA200007052692c13)CESSCASTAA200007052692s7.sn.14)
# 21	y	y	CCONJ	cc	_	23	cc	23:cc	_
# 22	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	23	det	23:det	Entity=(CESSCASTAA200007052692s7.sn.53--2-gstype:gen,HomoDD
# 23	separación	separación	NOUN	ncfs000	Gender=Fem|Number=Sing	7	conj	7:conj	_
# 24	de	de	ADP	sps00	_	27	case	27:case	_
# 25	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	27	det	27:det	Entity=(CESSCASTAA200007052692c12--3-gstype:gen,HomoDD
# 26	malos	malo	ADJ	aq0mp0	Gender=Masc|Number=Plur	27	amod	27:amod	_
# 27	elementos	elemento	NOUN	ncmp000	Gender=Masc|Number=Plur	23	nmod	23:nmod	_
# 28	que	que	PRON	pr0cn000	PronType=Int,Rel	29	nsubj	29:nsubj	Entity=(CESSCASTAA200007052692c12--1-CorefType:ident,gstype:gen)
# 29	viven	vivir	VERB	vmip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	27	acl	27:acl	_
# 30	en	en	ADP	sps00	_	32	case	32:case	_
# 31	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	32	det	32:det	Entity=(CESSCASTAA200007052692c13--2-CorefType:ident,gstype:gen
# 32	instalaciones	instalación	NOUN	ncfp000	Gender=Fem|Number=Plur	29	obl	29:obl	SpaceAfter=No|Entity=CESSCASTAA200007052692c13)CESSCASTAA200007052692c12)CESSCASTAA200007052692s7.sn.53)
# 33	"	"	PUNCT	fe	PunctType=Quot	7	punct	7:punct	SpaceAfter=No|Entity=CESSCASTAA200007052692s7.sn.12)
# 34	,	,	PUNCT	fc	PunctType=Comm	37	punct	37:punct	_
# 35	según	según	ADP	sps00	_	37	case	37:case	_
# 36	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	37	det	37:det	Entity=(CESSCASTAA200007052692c1-organization-2-CorefType:ident,gstype:spec
# 37	ACNUR	ACNUR	PROPN	np00000	_	4	obl	4:obl	SpaceAfter=No|Entity=CESSCASTAA200007052692c1)
# 38	.	.	PUNCT	fp	PunctType=Peri	4	punct	4:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s8
# # text = Esos "elementos malos" son los miembros de las milicias pro-indonesias, organizadas por el Ejército de Indonesia en Timor Oriental para acabar con los partidarios de la independencia de la antigua colonia portuguesa.
# 1	Esos	ese	DET	dd0mp0	Gender=Masc|Number=Plur|PronType=Dem	3	det	3:det	Entity=(CESSCASTAA200007052692c12--3-CorefType:ident,gstype:gen
# 2	"	"	PUNCT	fe	PunctType=Quot	3	punct	3:punct	SpaceAfter=No
# 3	elementos	elemento	NOUN	ncmp000	Gender=Masc|Number=Plur	8	nsubj	8:nsubj	_
# 4	malos	malo	ADJ	aq0mp0	Gender=Masc|Number=Plur	3	amod	3:amod	SpaceAfter=No
# 5	"	"	PUNCT	fe	PunctType=Quot	3	punct	3:punct	Entity=CESSCASTAA200007052692c12)
# 6	son	ser	AUX	vsip3p0	Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	8	cop	8:cop	_
# 7	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	8	det	8:det	Entity=(CESSCASTAA200007052692c12--2-CorefType:pred.definit,gstype:gen
# 8	miembros	miembro	NOUN	ncmp000	Gender=Masc|Number=Plur	0	root	0:root	_
# 9	de	de	ADP	sps00	_	11	case	11:case	_
# 10	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	11	det	11:det	Entity=(CESSCASTAA200007052692c15--2-gstype:gen,HomoDD
# 11	milicias	milicia	NOUN	ncfp000	Gender=Fem|Number=Plur	8	nmod	8:nmod	_
# 12	pro-indonesias	pro-indonesias	ADJ	_	_	11	amod	11:amod	SpaceAfter=No
# 13	,	,	PUNCT	fc	PunctType=Comm	14	punct	14:punct	_
# 14	organizadas	organizado	ADJ	aq0fpp	Gender=Fem|Number=Plur|VerbForm=Part	11	amod	11:amod	_
# 15	por	por	ADP	sps00	_	17	case	17:case	_
# 16	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	17	det	17:det	Entity=(CESSCASTAA200007052692c16-organization-2-gstype:spec
# 17	Ejército	Ejército	PROPN	np00000	_	14	obj	14:obj	MWE=Ejército_de_Indonesia|MWEPOS=PROPN
# 18	de	de	ADP	_	_	19	case	19:case	_
# 19	Indonesia	Indonesia	PROPN	_	_	17	flat	17:flat	Entity=CESSCASTAA200007052692c16)
# 20	en	en	ADP	sps00	_	21	case	21:case	_
# 21	Timor	Timor	PROPN	np00000	_	14	obl	14:obl	MWE=Timor_Oriental|MWEPOS=PROPN|Entity=(CESSCASTAA200007052692c14-place-1-CorefType:ident,gstype:spec
# 22	Oriental	Oriental	PROPN	_	_	21	flat	21:flat	Entity=CESSCASTAA200007052692c14)
# 23	para	para	ADP	sps00	_	24	mark	24:mark	_
# 24	acabar	acabar	VERB	vmn0000	VerbForm=Inf	14	advcl	14:advcl	_
# 25	con	con	ADP	sps00	_	27	case	27:case	_
# 26	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	27	det	27:det	Entity=(CESSCASTAA200007052692s8.sn.57--2-gstype:gen,HomoDD
# 27	partidarios	partidario	NOUN	ncmp000	Gender=Masc|Number=Plur	24	obj	24:obj	_
# 28	de	de	ADP	sps00	_	30	case	30:case	_
# 29	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	30	det	30:det	Entity=(CESSCASTAA200007052692s8.sn.65--2-gstype:gen,HomoDD
# 30	independencia	independencia	NOUN	ncfs000	Gender=Fem|Number=Sing	27	nmod	27:nmod	_
# 31	de	de	ADP	sps00	_	34	case	34:case	_
# 32	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	34	det	34:det	Entity=(CESSCASTAA200007052692c14-place-3-CorefType:ident,gstype:spec
# 33	antigua	antiguo	ADJ	aq0fs0	Gender=Fem|Number=Sing	34	amod	34:amod	_
# 34	colonia	colonia	NOUN	ncfs000	Gender=Fem|Number=Sing	30	nmod	30:nmod	_
# 35	portuguesa	portugués	ADJ	aq0fs0	Gender=Fem|Number=Sing	34	amod	34:amod	SpaceAfter=No|Entity=CESSCASTAA200007052692c14)CESSCASTAA200007052692s8.sn.65)CESSCASTAA200007052692s8.sn.57)CESSCASTAA200007052692c15)CESSCASTAA200007052692c12)
# 36	.	.	PUNCT	fp	PunctType=Peri	8	punct	8:punct	_
#
#
# # sent_id = CESS-CAST-AA-20000705-2692-s9
# # text = Hace dos semanas, la ACNUR debió suspender sus actividades en los campamentos cercanos a Kupang tras los ataques de las milicias pro-indonesias a su personal, ante la presencia de los militares indonesios.
# 1	Hace	hacer	VERB	vmip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	8	advcl	8:advcl	Entity=(CESSCASTAA200007052692s9.sn.2--1-gstype:gen
# 2	dos	dos	NUM	dn0cp0	Number=Plur|NumType=Card	3	nummod	3:nummod	_
# 3	semanas	semana	NOUN	ncfp000	Gender=Fem|Number=Plur	1	obj	1:obj	SpaceAfter=No
# 4	,	,	PUNCT	fc	PunctType=Comm	3	punct	3:punct	Entity=CESSCASTAA200007052692s9.sn.2)
# 5	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	6	det	6:det	Entity=(CESSCASTAA200007052692c1-organization-2-CorefType:ident,gstype:spec
# 6	ACNUR	ACNUR	PROPN	np00000	_	8	nsubj	8:nsubj	Entity=CESSCASTAA200007052692c1)
# 7	debió	deber	AUX	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	8	aux	8:aux	_
# 8	suspender	suspender	VERB	vmn0000	VerbForm=Inf	0	root	0:root	_
# 9	sus	su	DET	dp3cp0	Number=Plur|Person=3|Poss=Yes|PronType=Prs	10	det	10:det	Entity=(CESSCASTAA200007052692c8--2-CorefType:ident,gstype:gen(CESSCASTAA200007052692c1-organization-1-CorefType:ident,gstype:spec)
# 10	actividades	actividad	NOUN	ncfp000	Gender=Fem|Number=Plur	8	obj	8:obj	_
# 11	en	en	ADP	sps00	_	13	case	13:case	_
# 12	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	13	det	13:det	Entity=(CESSCASTAA200007052692c6--2-CorefType:ident,gstype:gen,HomoDD
# 13	campamentos	campamento	NOUN	ncmp000	Gender=Masc|Number=Plur	10	nmod	10:nmod	_
# 14	cercanos	cercano	ADJ	aq0mp0	Gender=Masc|Number=Plur	13	amod	13:amod	_
# 15	a	a	ADP	sps00	_	16	case	16:case	_
# 16	Kupang	Kupang	PROPN	np00000	_	14	nmod	14:nmod	Entity=(CESSCASTAA200007052692c5-place-1-CorefType:ident,gstype:spec)CESSCASTAA200007052692c6)CESSCASTAA200007052692c8)
# 17	tras	tras	ADP	sps00	_	19	case	19:case	_
# 18	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	19	det	19:det	Entity=(CESSCASTAA200007052692s9.sn.41--2-gstype:gen,HomoDD
# 19	ataques	ataque	NOUN	ncmp000	Gender=Masc|Number=Plur	8	obl	8:obl	_
# 20	de	de	ADP	sps00	_	22	case	22:case	_
# 21	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	22	det	22:det	Entity=(CESSCASTAA200007052692c15--2-CorefType:ident,gstype:gen,HomoDD
# 22	milicias	milicia	NOUN	ncfp000	Gender=Fem|Number=Plur	19	nmod	19:nmod	_
# 23	pro-indonesias	pro-indonesias	ADJ	_	_	22	amod	22:amod	Entity=CESSCASTAA200007052692c15)
# 24	a	a	ADP	sps00	_	26	case	26:case	_
# 25	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	26	det	26:det	Entity=(CESSCASTAA200007052692s9.sn.60--2-gstype:gen(CESSCASTAA200007052692c1-organization-1-CorefType:ident,gstype:spec)
# 26	personal	personal	NOUN	ncms000	Gender=Masc|Number=Sing	19	nmod	19:nmod	SpaceAfter=No|Entity=CESSCASTAA200007052692s9.sn.60)
# 27	,	,	PUNCT	fc	PunctType=Comm	30	punct	30:punct	_
# 28	ante	ante	ADP	sps00	_	30	case	30:case	_
# ...
# 10	,	,	PUNCT	fc	PunctType=Comm	8	punct	8:punct	Entity=CESSCASTAA2000113024674c1)CESSCASTAA2000113024674c1)
# 11	expresó	expresar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 12	hoy	hoy	ADV	rg	_	11	advmod	11:advmod	_
# 13	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	14	det	14:det	Entity=(CESSCASTAA2000113024674c5--2-gstype:gen(CESSCASTAA2000113024674c1-person-1-CorefType:ident,gstype:spec)
# 14	satisfacción	satisfacción	NOUN	ncfs000	Gender=Fem|Number=Sing	11	obj	11:obj	_
# 15	por	por	ADP	sps00	_	17	case	17:case	_
# 16	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	17	det	17:det	Entity=(CESSCASTAA2000113024674c2--2-gstype:gen,HomoDD
# 17	concesión	concesión	NOUN	ncfs000	Gender=Fem|Number=Sing	14	nmod	14:nmod	_
# 18	de	de	ADP	sps00	_	20	case	20:case	_
# 19	un	uno	DET	di0ms0	Definite=Ind|Gender=Masc|Number=Sing|PronType=Art	20	det	20:det	Entity=(CESSCASTAA2000113024674c3--2-gstype:gen
# 20	crédito	crédito	NOUN	ncms000	Gender=Masc|Number=Sing	17	nmod	17:nmod	_
# 21	de	de	ADP	sps00	_	23	case	23:case	_
# 22	1.000	1000	NUM	_	NumForm=Digit|NumType=Card	23	nummod	23:nummod	Entity=(CESSCASTAA2000113024674s1.sn.51-number-2-gstype:spec
# 23	millones	millón	NOUN	ncmp000	Gender=Masc|Number=Plur	20	nmod	20:nmod	_
# 24	de	de	ADP	sps00	_	25	case	25:case	_
# 25	pesetas	peseta	NOUN	zm	NumForm=Digit	23	nmod	23:nmod	Entity=(CESSCASTAA2000113024674s1.sn.59-number-1-gstype:spec)CESSCASTAA2000113024674s1.sn.51)CESSCASTAA2000113024674c3)
# 26	a	a	ADP	sps00	_	28	case	28:case	_
# 27	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	28	det	28:det	Entity=(CESSCASTAA2000113024674c12-organization-2-gstype:spec
# 28	Minas	Minas	PROPN	np00000	_	17	nmod	17:nmod	MWE=Minas_de_Río_Tinto_Sociedad_Anónima_Laboral|MWEPOS=PROPN
# 29	de	de	ADP	_	_	30	case	30:case	_
# 30	Río	Río	PROPN	_	_	28	flat	28:flat	_
# 31	Tinto	Tinto	PROPN	_	_	30	flat	30:flat	_
# 32	Sociedad	Sociedad	PROPN	_	_	30	flat	30:flat	_
# 33	Anónima	Anónima	PROPN	_	_	30	flat	30:flat	_
# 34	Laboral	Laboral	PROPN	_	_	30	flat	30:flat	SpaceAfter=No|Entity=CESSCASTAA2000113024674c12)CESSCASTAA2000113024674c2)CESSCASTAA2000113024674c5)
# 35	,	,	PUNCT	fc	PunctType=Comm	37	punct	37:punct	_
# 36	y	y	CCONJ	cc	_	37	cc	37:cc	_
# 36.1	_	_	PRON	p	_	_	_	37:nsubj	Entity=(CESSCASTAA2000113024674c1-person-1-CorefType:ident,gstype:spec)
# 37	deseó	desear	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	11	conj	11:conj	_
# 38	que	que	SCONJ	cs	_	55	mark	55:mark	_
# 39	"	"	PUNCT	fe	PunctType=Quot	55	punct	55:punct	SpaceAfter=No
# 40	igual	igual	ADJ	cs	_	43	mark	43:mark	MWE=igual_que|MWEPOS=SCONJ
# 41	que	que	SCONJ	_	_	40	fixed	40:fixed	_
# 42	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	43	aux	43:aux	_
# 43	hecho	hacer	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	55	advcl	55:advcl	_
# 44	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	45	det	45:det	Entity=(CESSCASTAA2000113024674c11-organization-2-gstype:spec
# 45	Gobierno	Gobierno	PROPN	np00000	_	43	nsubj	43:nsubj	_
# 46	de	de	ADP	sps00	_	47	case	47:case	_
# 47	España	España	PROPN	np00000	_	45	nmod	45:nmod	SpaceAfter=No|Entity=(CESSCASTAA2000113024674s1.sn.95-place-1-gstype:spec)CESSCASTAA2000113024674c11)
# 48	,	,	PUNCT	fc	PunctType=Comm	43	punct	43:punct	_
# 49	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	50	det	50:det	Entity=(CESSCASTAA2000113024674c15--5-gstype:gen
# 50	resto	resto	NOUN	ncms000	Gender=Masc|Number=Sing	53	nmod	53:nmod	_
# 51	de	de	ADP	sps00	_	50	case	50:case	_
# 52	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	50	det	50:det	_
# 53	administraciones	administración	NOUN	ncfp000	Gender=Fem|Number=Plur	55	nsubj	55:nsubj	Entity=CESSCASTAA2000113024674c15)
# 54	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	55	obj	55:obj	_
# 55	impliquen	implicar	VERB	vmsp3p0	Mood=Sub|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin	37	ccomp	37:ccomp	_
# 56	a	a	ADP	rg	_	55	advmod	55:advmod	MWE=a_fondo|MWEPOS=ADV
# 57	fondo	fondo	NOUN	_	_	56	fixed	56:fixed	SpaceAfter=No
# 58	"	"	PUNCT	fe	PunctType=Quot	55	punct	55:punct	SpaceAfter=No
# 59	.	.	PUNCT	fp	PunctType=Peri	11	punct	11:punct	_
#
#
# # sent_id = CESS-CAST-AA-20001130-24674-s2
# # text = Arenas se refirió en declaraciones a los periodistas a la decisión de la Comisión Delegada para Asuntos Económicos de conceder el crédito, que ha propiciado que los seis mineros encerrados desde hacía 21 días en el Pozo Alfredo a 500 metros de profundidad salieran a la superficie esta tarde tras conocer esta decisión.
# 1	Arenas	Arenas	PROPN	np00000	_	3	nsubj	3:nsubj	Entity=(CESSCASTAA2000113024674c1-person-1-CorefType:ident,gstype:spec)
# 2	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	3	expl:pv	3:expl:pv	_
# 3	refirió	referir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 4	en	en	ADP	sps00	_	5	case	5:case	_
# 5	declaraciones	declaración	NOUN	ncfp000	Gender=Fem|Number=Plur	3	obl	3:obl	Entity=(CESSCASTAA2000113024674s2.sn.12--1-gstype:gen
# 6	a	a	ADP	sps00	_	8	case	8:case	_
# 7	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	8	det	8:det	Entity=(CESSCASTAA2000113024674s2.sn.18--2-gstype:gen,HomoDD
# 8	periodistas	periodista	NOUN	nccp000	Number=Plur	5	nmod	5:nmod	Entity=CESSCASTAA2000113024674s2.sn.18)CESSCASTAA2000113024674s2.sn.12)
# 9	a	a	ADP	sps00	_	11	case	11:case	_
# 10	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	11	det	11:det	Entity=(CESSCASTAA2000113024674c2--2-CorefType:ident,gstype:gen,HomoDD
# 11	decisión	decisión	NOUN	ncfs000	Gender=Fem|Number=Sing	3	obj	3:obj	_
# 12	de	de	ADP	sps00	_	14	case	14:case	_
# 13	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	14	det	14:det	Entity=(CESSCASTAA2000113024674s2.sn.34-organization-2-gstype:spec
# 14	Comisión	Comisión	PROPN	np00000	_	11	nmod	11:nmod	MWE=Comisión_Delegada_para_Asuntos_Económicos|MWEPOS=PROPN
# 15	Delegada	Delegada	PROPN	_	_	14	flat	14:flat	_
# 16	para	para	ADP	_	_	17	case	17:case	_
# 17	Asuntos	Asuntos	PROPN	_	_	14	flat	14:flat	_
# 18	Económicos	Económicos	PROPN	_	_	14	flat	14:flat	Entity=CESSCASTAA2000113024674s2.sn.34)
# 19	de	de	ADP	sps00	_	20	mark	20:mark	_
# 20	conceder	conceder	VERB	vmn0000	VerbForm=Inf	11	acl	11:acl	_
# 21	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	22	det	22:det	Entity=(CESSCASTAA2000113024674c3--2-CorefType:ident,gstype:gen
# 22	crédito	crédito	NOUN	ncms000	Gender=Masc|Number=Sing	20	obj	20:obj	SpaceAfter=No|Entity=CESSCASTAA2000113024674c3)
# 23	,	,	PUNCT	fc	PunctType=Comm	26	punct	26:punct	_
# 24	que	que	PRON	pr0cn000	PronType=Int,Rel	26	nsubj	26:nsubj	Entity=(CESSCASTAA2000113024674c2--1-CorefType:ident,gstype:gen)
# 25	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	26	aux	26:aux	_
# 26	propiciado	propiciar	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	11	acl	11:acl	_
# 27	que	que	SCONJ	cs	_	45	mark	45:mark	_
# 28	los	el	DET	da0mp0	Definite=Def|Gender=Masc|Number=Plur|PronType=Art	30	det	30:det	Entity=(CESSCASTAA2000113024674s2.sn.60--3-gstype:gen,HomoDD
# 29	seis	seis	NUM	dn0cp0	Number=Plur|NumType=Card	28	nummod	28:nummod	_
# 30	mineros	minero	NOUN	ncmp000	Gender=Masc|Number=Plur	45	nsubj	45:nsubj	_
# 31	encerrados	encerrado	ADJ	aq0mpp	Gender=Masc|Number=Plur|VerbForm=Part	30	amod	30:amod	_
# 32	desde	desde	ADP	sps00	_	33	case	33:case	_
# 33	hacía	hacer	VERB	vmii3s0	Mood=Ind|Number=Sing|Person=3|Tense=Imp|VerbForm=Fin	31	advcl	31:advcl	Entity=(CESSCASTAA2000113024674s2.sn.72--1-gstype:gen
# 34	21	21	NUM	_	NumForm=Digit|NumType=Card	35	nummod	35:nummod	_
# 35	días	día	NOUN	ncmp000	Gender=Masc|Number=Plur	33	obj	33:obj	Entity=CESSCASTAA2000113024674s2.sn.72)
# 36	en	en	ADP	sps00	_	38	case	38:case	_
# 37	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	38	det	38:det	Entity=(CESSCASTAA2000113024674s2.sn.79-place-2-gstype:spec
# 38	Pozo	Pozo	PROPN	np00000	_	31	obl	31:obl	MWE=Pozo_Alfredo|MWEPOS=PROPN
# 39	Alfredo	Alfredo	PROPN	_	_	38	flat	38:flat	Entity=CESSCASTAA2000113024674s2.sn.79)
# 40	a	a	ADP	sps00	_	42	case	42:case	_
# 41	500	500	NUM	_	NumForm=Digit|NumType=Card	42	nummod	42:nummod	Entity=(CESSCASTAA2000113024674s2.sn.87-number-2-gstype:spec
# 42	metros	metro	NOUN	ncmp000	Gender=Masc|Number=Plur	31	obl	31:obl	_
# 43	de	de	ADP	sps00	_	44	case	44:case	_
# 44	profundidad	profundidad	NOUN	ncfs000	Gender=Fem|Number=Sing	42	nmod	42:nmod	Entity=CESSCASTAA2000113024674s2.sn.87)CESSCASTAA2000113024674s2.sn.60)
# 45	salieran	salir	VERB	vmsi3p0	Mood=Sub|Number=Plur|Person=3|Tense=Imp|VerbForm=Fin	26	ccomp	26:ccomp	_
# 46	a	a	ADP	sps00	_	48	case	48:case	_
# 47	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	48	det	48:det	Entity=(CESSCASTAA2000113024674s2.sn.103--2-gstype:gen,HomoDD
# 48	superficie	superficie	NOUN	ncfs000	Gender=Fem|Number=Sing	45	obl	45:obl	Entity=CESSCASTAA2000113024674s2.sn.103)
# 49	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	50	det	50:det	Entity=(CESSCASTAA2000113024674s2.sn.108--2-gstype:gen
# 50	tarde	tarde	NOUN	ncfs000	Gender=Fem|Number=Sing	45	obl	45:obl	Entity=CESSCASTAA2000113024674s2.sn.108)
# 51	tras	tras	ADP	sps00	_	52	mark	52:mark	_
# 52	conocer	conocer	VERB	vmn0000	VerbForm=Inf	45	advcl	45:advcl	_
# 53	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	54	det	54:det	Entity=(CESSCASTAA2000113024674c2--2-CorefType:ident,gstype:gen
# 54	decisión	decisión	NOUN	ncfs000	Gender=Fem|Number=Sing	52	obj	52:obj	SpaceAfter=No|Entity=CESSCASTAA2000113024674c2)CESSCASTAA2000113024674c2)
# 55	.	.	PUNCT	fp	PunctType=Peri	3	punct	3:punct	_
#
#
# # sent_id = CESS-CAST-AA-20001130-24674-s3
# # text = El secretario general del PP expresó su "gran satisfacción" por esta noticia y dijo que esta resolución se ha producido gracias a las gestiones llevadas a cabo por el alcalde de Huelva, Pedro Rodríguez (PP); la presidenta del PP andaluz, Teófila Martínez, y el secretario general del PP-A, Antonio Sanz.
# 1	El	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	2	det	2:det	Entity=(CESSCASTAA2000113024674c1-person-2-CorefType:ident,gstype:spec
# 2	secretario	secretario	NOUN	ncms000	Gender=Masc|Number=Sing	7	nsubj	7:nsubj	_
# 3	general	general	ADJ	aq0cs0	Number=Sing	2	amod	2:amod	_
# 4-5	del	_	_	_	_	_	_	_	_
# 4	de	de	ADP	spcms	_	6	case	6:case	_
# 5	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	6	det	6:det	_
# 6	PP	PP	PROPN	np00000	_	2	nmod	2:nmod	Entity=(CESSCASTAA2000113024674c4-organization-1-CorefType:ident,gstype:spec)CESSCASTAA2000113024674c1)
# 7	expresó	expresar	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	0	root	0:root	_
# 8	su	su	DET	dp3cs0	Number=Sing|Person=3|Poss=Yes|PronType=Prs	11	det	11:det	Entity=(CESSCASTAA2000113024674c5--4-CorefType:ident,gstype:gen(CESSCASTAA2000113024674c1-person-1-CorefType:ident,gstype:spec)
# 9	"	"	PUNCT	fe	PunctType=Quot	11	punct	11:punct	SpaceAfter=No
# 10	gran	gran	ADJ	aq0cs0	Number=Sing	11	amod	11:amod	_
# 11	satisfacción	satisfacción	NOUN	ncfs000	Gender=Fem|Number=Sing	7	obj	7:obj	SpaceAfter=No
# 12	"	"	PUNCT	fe	PunctType=Quot	11	punct	11:punct	_
# 13	por	por	ADP	sps00	_	15	case	15:case	_
# 14	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	15	det	15:det	Entity=(CESSCASTAA2000113024674c2--2-CorefType:ident,gstype:gen
# 15	noticia	noticia	NOUN	ncfs000	Gender=Fem|Number=Sing	11	nmod	11:nmod	Entity=CESSCASTAA2000113024674c2)CESSCASTAA2000113024674c5)
# 16	y	y	CCONJ	cc	_	17	cc	17:cc	_
# 16.1	_	_	PRON	p	_	_	_	17:nsubj	Entity=(CESSCASTAA2000113024674c1-person-1-CorefType:ident,gstype:spec)
# 17	dijo	decir	VERB	vmis3s0	Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin	7	conj	7:conj	_
# 18	que	que	SCONJ	cs	_	23	mark	23:mark	_
# 19	esta	este	DET	dd0fs0	Gender=Fem|Number=Sing|PronType=Dem	20	det	20:det	Entity=(CESSCASTAA2000113024674c2--2-CorefType:ident,gstype:gen
# 20	resolución	resolución	NOUN	ncfs000	Gender=Fem|Number=Sing	23	nsubj	23:nsubj	Entity=CESSCASTAA2000113024674c2)
# 21	se	él	PRON	p0300000	Case=Acc|Person=3|PrepCase=Npr|PronType=Prs|Reflex=Yes	23	expl:pv	23:expl:pv	_
# 22	ha	haber	AUX	vaip3s0	Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin	23	aux	23:aux	_
# 23	producido	producir	VERB	vmp00sm	Gender=Masc|Number=Sing|Tense=Past|VerbForm=Part	17	ccomp	17:ccomp	_
# 24	gracias	gracias	NOUN	sps00	_	27	case	27:case	MWE=gracias_a|MWEPOS=ADP
# 25	a	a	ADP	_	_	24	fixed	24:fixed	_
# 26	las	el	DET	da0fp0	Definite=Def|Gender=Fem|Number=Plur|PronType=Art	27	det	27:det	Entity=(CESSCASTAA2000113024674s3.sn.59--2-gstype:gen,HomoDD
# 27	gestiones	gestión	NOUN	ncfp000	Gender=Fem|Number=Plur	23	obl	23:obl	_
# 28	llevadas	llevado	ADJ	aq0fpp	_	27	amod	27:amod	MWE=llevadas_a_cabo|MWEPOS=ADJ
# 29	a	a	ADP	_	_	30	case	30:case	_
# 30	cabo	cabo	NOUN	_	_	28	nmod	28:nmod	_
# 31	por	por	ADP	sps00	_	33	case	33:case	_
# 32	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	33	det	33:det	Entity=(CESSCASTAA2000113024674c7-person-2-gstype:spec
# 33	alcalde	alcalde	NOUN	ncms000	Gender=Masc|Number=Sing	28	obj	28:obj	_
# 34	de	de	ADP	sps00	_	35	case	35:case	_
# 35	Huelva	Huelva	PROPN	np00000	_	33	nmod	33:nmod	SpaceAfter=No|Entity=(CESSCASTAA2000113024674c18-place-1-gstype:spec)
# 36	,	,	PUNCT	fc	PunctType=Comm	37	punct	37:punct	Entity=(CESSCASTAA2000113024674c7-person-2-CorefType:pred.definit,gstype:spec
# 37	Pedro	Pedro	PROPN	np00000	_	33	appos	33:appos	MWE=Pedro_Rodríguez|MWEPOS=PROPN
# 38	Rodríguez	Rodríguez	PROPN	_	_	37	flat	37:flat	Entity=CESSCASTAA2000113024674c7)
# 39	(	(	PUNCT	fpa	PunctSide=Ini|PunctType=Brck	40	punct	40:punct	SpaceAfter=No|Entity=(CESSCASTAA2000113024674c4-organization-2-CorefType:ident,gstype:spec
# 40	PP	PP	PROPN	np00000	_	33	appos	33:appos	SpaceAfter=No
# 41	)	)	PUNCT	fpt	PunctSide=Fin|PunctType=Brck	40	punct	40:punct	SpaceAfter=No|Entity=CESSCASTAA2000113024674c4)CESSCASTAA2000113024674c7)
# 42	;	;	PUNCT	fx	PunctType=Semi	44	punct	44:punct	_
# 43	la	el	DET	da0fs0	Definite=Def|Gender=Fem|Number=Sing|PronType=Art	44	det	44:det	Entity=(CESSCASTAA2000113024674c8-person-2-gstype:spec
# 44	presidenta	presidenta	NOUN	ncfs000	Gender=Fem|Number=Sing	33	appos	33:appos	_
# 45-46	del	_	_	_	_	_	_	_	_
# 45	de	de	ADP	spcms	_	47	case	47:case	_
# 46	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	47	det	47:det	_
# 47	PP	PP	PROPN	np00000	_	44	nmod	44:nmod	Entity=(CESSCASTAA2000113024674c10-organization-1-gstype:spec
# 48	andaluz	andaluz	ADJ	aq0ms0	Gender=Masc|Number=Sing	47	amod	47:amod	SpaceAfter=No|Entity=CESSCASTAA2000113024674c10)
# 49	,	,	PUNCT	fc	PunctType=Comm	50	punct	50:punct	Entity=(CESSCASTAA2000113024674c8-person-2-CorefType:pred.definit,gstype:spec
# 50	Teófila	Teófila	PROPN	np00000	_	44	appos	44:appos	MWE=Teófila_Martínez|MWEPOS=PROPN
# 51	Martínez	Martínez	PROPN	_	_	50	flat	50:flat	SpaceAfter=No
# 52	,	,	PUNCT	fc	PunctType=Comm	50	punct	50:punct	Entity=CESSCASTAA2000113024674c8)CESSCASTAA2000113024674c8)
# 53	y	y	CCONJ	cc	_	55	cc	55:cc	_
# 54	el	el	DET	da0ms0	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	55	det	55:det	Entity=(CESSCASTAA2000113024674c9-person-2-gstype:spec
# 55	secretario	secretario	NOUN	ncms000	Gender=Masc|Number=Sing	33	conj	33:conj	_
# 56	general	general	ADJ	aq0cs0	Number=Sing	55	amod	55:amod	_
# 57-58	del	_	_	_	_	_	_	_	_
# 57	de	de	ADP	spcms	_	59	case	59:case	_
# 58	el	el	DET	_	Definite=Def|Gender=Masc|Number=Sing|PronType=Art	59	det	59:det	_
# 59	PP-A	PP	PROPN	np00000	_	55	nmod	55:nmod	SpaceAfter=No|Entity=(CESSCASTAA2000113024674c10-organization-1-CorefType:ident,gstype:spec)
# 60	,	,	PUNCT	fc	PunctType=Comm	61	punct	61:punct	Entity=(CESSCASTAA2000113024674c9-person-2-CorefType:pred.definit,gstype:spec
# 61	Antonio	Antonio	PROPN	np00000	_	55	appos	55:appos	MWE=Antonio_Sanz|MWEPOS=PROPN
# 62	Sanz	Sanz	PROPN	_	_	61	flat	61:flat	SpaceAfter=No|Entity=CESSCASTAA2000113024674c9)CESSCASTAA2000113024674c9)CESSCASTAA2000113024674s3.sn.59)
# 63	.	.	PUNCT	fp	PunctType=Peri	7	punct	7:punct	_
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#@title Estructura de los tokens etiquetados del corpus
tokenlist[1]
# Out:
# {'deprel': 'det',
#  'deps': [('det', 5)],
#  'feats': {'Definite': 'Def',
#   'Gender': 'Masc',
#   'Number': 'Sing',
#   'PronType': 'Art'},
#  'form': 'El',
#  'head': 5,
#  'id': 2,
#  'lemma': 'el',
#  'misc': {'Entity': '(CESSCASTP2002080117s20.sn.3--1-gstype:gen'},
#  'upos': 'DET',
#  'xpos': 'da0ms0'}

# %%
tokenlist[1]['form']+'|'+tokenlist[1]['upos']
# Out:
# 'El|DET'

# %% [markdown]
# ## Entrenamiento del modelo - Calculo de conteos:
#
# * tags (tags) `tagCountDict`: $C(tag)$
# * emisiones (word|tag) `emissionProbDict`: $C(word|tag)$
# * transiciones (tag|prevtag) `transitionDict`: $C(tag|prevtag)$

# %%
tagCountDict = {} 
emissionDict = {}
transitionDict = {}

tagtype = 'upos'
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

# Calculando conteos (pre-probabilidades)
for tokenlist in parse_incr(data_file):
  prevtag = None
  for token in tokenlist:

    # C(tag)
    tag = token[tagtype]
    if tag in tagCountDict.keys():
      tagCountDict[tag] += 1
    else:
      tagCountDict[tag] = 1

    # C(word|tag) -> probabilidades emision
    wordtag = token['form'].lower()+'|'+token[tagtype] # (word|tag)
    if wordtag in emissionDict.keys():
      emissionDict[wordtag] = emissionDict[wordtag] + 1
    else:
      emissionDict[wordtag] = 1

    #  C(tag|tag_previo) -> probabilidades transición
    if prevtag is None:
      prevtag = tag
      continue
    transitiontags = tag+'|'+prevtag
    if transitiontags in transitionDict.keys():
      transitionDict[transitiontags] = transitionDict[transitiontags] + 1
    else:
      transitionDict[transitiontags] = 1
    prevtag = tag
    
#transitionDict
#emissionDict
#tagCountDict

# %% [markdown]
# ## Entrenamiento del modelo - calculo de probabilidades
# * probabilidades de transición:
# $$P(tag|prevtag) = \frac{C(prevtag, tag)}{C(prevtag)}$$
#
# * probabilidades de emisión:
#  $$P(word|tag) = \frac{C(word|tag)}{C(tag)}$$

# %%
transitionProbDict = {} # matriz A
emissionProbDict = {} # matriz B

# transition Probabilities 
for key in transitionDict.keys():
  tag, prevtag = key.split('|')
  if tagCountDict[prevtag]>0:
    transitionProbDict[key] = transitionDict[key]/(tagCountDict[prevtag])
  else:
    print(key)

# emission Probabilities 
for key in emissionDict.keys():
  word, tag = key.split('|')
  if emissionDict[key]>0:
    emissionProbDict[key] = emissionDict[key]/tagCountDict[tag]
  else:
    print(key)

transitionProbDict['ADJ|ADJ']
#emissionProbDict
# Out:
# 0.030217452696978255

# %% [markdown]
# ## Guardar parámetros del modelo

# %%
import numpy as np
np.save('transitionHMM.npy', transitionProbDict)
np.save('emissionHMM.npy', emissionProbDict)
transitionProbdict = np.load('transitionHMM.npy', allow_pickle='TRUE').item()
transitionProbDict['ADJ|ADJ']
# Out:
# 0.030217452696978255
